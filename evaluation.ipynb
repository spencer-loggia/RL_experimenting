# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#load scores
PATH = './data/rand.csv'
data1 = pd.read_csv(PATH)
data2 = pd.read_csv('./data/thresh_rev_lr0001_2000.csv')
data5 = pd.read_csv('./data/conv_rangeDependent_2000.csv')
data4 = pd.read_csv('./data/rangeDependentPositive.csv')

# %%
plt.scatter(data1['iter'], data1['score'], c='blue')
plt.scatter(data4['iter'], data4['score'], c='red')
#plt.scatter(data5['iter'], data5['score'], c='purple')
# plt.scatter(data3['iter'], data3['score'], c='green')
